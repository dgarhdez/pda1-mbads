# %% [markdown]
# # Session 02: Practice
#
# * Variables and types
# * Arithmetic operations
# * Comparison operators
# * Logical operators

# %% [markdown]
# ## Variables and types
#
# * Create a variable named `name` and assign it a string with your name.
# * Create a variable named `age` and assign it an integer with your age.
# * Create a variable named `height` and assign it a float with your height.
# * Create a variable named `is_student` and assign it a boolean with your student status.

# %% [markdown]
# ## Arithmetic, Comparison and Logical Operators
#
# Build programs to solve the following operations, one cell for each operation:
#
# * $ ((3 + 4) \cdot 5) >= 20$
# * $ 3 + 4 \cdot 5 / 2$
# * $ 3^2 + 4^2 = 5^2$
# * $ (3^2 + 4^2 = 5^2) \text{or not} (17 // 3 > 6)$

# %% [markdown]
# ## Pizza restaurant
#
# A pizza restaurant offers three sizes of pizza: small, medium, and large. The prices and radius for each size are as follows:
#
# | Size | Price EUR | Radius cm |
# |------|-------|--------|
# | S    | 11    | 12     |
# | M    | 20    | 25     |
# | L    | 30    | 35     |

# %% [markdown]
# ### Exercise 1
#
# Which size provides the most pizza per euro?
#
# Hint1: use the area of a circle formula: $\text{Area} = \pi \cdot \text{radius}^2$.
#
# Hint2: you can use `3.1415` as an approximation for $\pi$.

# %% [markdown]
# ### Exercise 2
#
# Is it better to get 2 small pizzas or 1 medium pizza?
#
# What about 3 small pizzas or 1 large pizza?
#
# What about 2 medium pizzas or 1 large pizza?

# %% [markdown]
# ### Exercise 3
#
# 2 famous professional eaters are having a pizza eating contest.
#
# * The first ate 3 small pizzas, 2 medium pizzas, and 0.75 large pizza.
# * The second ate 2 small pizzas, 3 medium pizza, and 0.5 large pizza.
#
# Who won?
#
# How much total pizza (in cm2) did each one of them eat?

# %% [markdown]
# ## Wind power generation
#
# The formula that relates wind speed and power generation is:
#
# $$P = 0.5 \cdot A \cdot \rho \cdot C_p \cdot v^3$$
#
# $$ A = \pi \cdot r^2$$
#
# $$ r = \frac{D}{2}$$
#
# Where:
#
# * $P$ is the power generated in watts
# * $A$ is the area swept by the turbine blades in square meters
#
# * $D$ is the diameter of the turbine blades in meters, $r$ is the radius of the turbine blades in meters, $D = 2r$
# * $\rho$ is the air density in kg/m^3
# * $C_p$ is the power coefficient (a number between 0 and 0.59, let's assume it's 0.4)

# %% [markdown]
# ### Exercise 4
#
# A wind turbine has a rotor diameter of 30 meters.
#
# Calculate the power generated by the turbine at wind speed of 10 m/s.

# %% [markdown]
# ## Boolean operations and comparison
#
# ### Exercise 5
#
# * Create a variable named `is_raining` and assign it a boolean value indicating whether it is raining or not.
# * Create a variable named `is_weekend` and assign it a boolean value indicating whether it is weekend or not.
# * With these two variaables, create a new variable named `can_go_out` that is True if it is weekend and not raining, and False otherwise.

# %% [markdown]
# ## Business operations and taxes
#
# A company sells a product for 100 EUR. The cost of the product is 60 EUR.
#
# The total sales in units is 1520 for 2023, 2234 for 2024, and 3000 for 2025.
#
# The company has to pay a tax of 20% on the profit.
#
# ### Exercise 6
#
# Calculate the revenue per year

# %% [markdown]
# ### Exercise 7
#
# Calculate the costs per year

# %% [markdown]
# ### Exercise 8
#
# Calculate the profit per year

# %% [markdown]
# ### Exercise 9
#
# Calculate the taxes paid per year

# %% [markdown]
# ### Exercise 10
#
# The business owner faces a dilemma, about changing countries in which to operate.
#
# * Country 1: 25% tax, cost of product is 50 EUR
# * Country 2: 15% tax, cost of product is 70 EUR
#
# If the owner had moved to either of counties, what would have been the better option in 2024? Only take into account the final profit after taxes.
