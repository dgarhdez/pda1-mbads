# %% [markdown]
# # Session 3 Homework: Data Structures I - Lists and Tuples
#
# Complete the following exercises to practice working with lists and tuples.
#
# **Instructions:**
# - Write your code in the cells provided
# - Run each cell to verify your solution

# %% [markdown]
# ---
#
# ## Exercise 1: List Creation and Indexing
#
# Create a list called `weekdays` containing all days of the week (Monday through Sunday).
#
# Then print:
# 1. The first day
# 2. The last day
# 3. The middle day (Wednesday)
# 4. The weekend days using slicing

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2: List Operations
#
# Starting with the list of numbers below:
# 1. Add 100 to the end of the list
# 2. Insert 0 at the beginning
# 3. Remove the value 30 from the list
# 4. Sort the list in descending order
#
# Print the list after each operation.

# %%
numbers = [50, 20, 30, 40, 10]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3: List Statistics
#
# Given the list of exam scores below, calculate and print:
# 1. The highest score
# 2. The lowest score
# 3. The total of all scores
# 4. The average score
# 5. How many scores are above average

# %%
scores = [78, 92, 85, 67, 90, 73, 88, 95, 70, 82]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4: List Slicing
#
# Given the list of letters, use slicing to:
# 1. Get the first 5 letters
# 2. Get the last 5 letters
# 3. Get every third letter
# 4. Reverse the list using slicing

# %%
letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Working with Tuples
#
# Create a tuple called `coordinates` with 3 points: (0, 0), (3, 4), (6, 8).
#
# Then:
# 1. Access and print the second point
# 2. Unpack the first point into variables `x1` and `y1`
# 3. Calculate the distance from origin (0,0) to the second point using: distance = √(x² + y²)

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Nested Lists
#
# Create a 3x3 matrix (list of lists) representing a tic-tac-toe board:
# ```
# X | O | X
# ---------
# O | X | O
# ---------
# X | O | X
# ```
#
# Then:
# 1. Print the center element
# 2. Print the diagonal from top-left to bottom-right
# 3. Print the middle row

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7: List Methods Practice
#
# Given the shopping list:
# 1. Check if "milk" is in the list
# 2. Count how many times "eggs" appears
# 3. Find the index of "bread"
# 4. Create a copy of the list and sort it alphabetically
# 5. Extend the original list with ["cheese", "yogurt"]

# %%
shopping = ["milk", "bread", "eggs", "butter", "eggs", "apples"]

# Your code here

# %% [markdown]
# ---
#
# ## Bonus Exercise: Student Records
#
# Create a list of tuples where each tuple contains (name, age, grade).
# Add at least 5 students.
#
# Then find:
# 1. The oldest student
# 2. The student with the highest grade
# 3. The average age of all students

# %%
# Your code here
