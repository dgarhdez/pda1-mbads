# %% [markdown]
# # Session 5 Homework: Strings and Text Processing
#
# Complete the following exercises to practice working with strings.

# %% [markdown]
# ---
#
# ## Exercise 1: String Basics
#
# Given the string below:
# 1. Print its length
# 2. Print the first 5 characters
# 3. Print the last 6 characters
# 4. Print every other character

# %%
text = "Python Programming"

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2: String Methods
#
# Using the string below, perform these operations:
# 1. Convert to uppercase
# 2. Convert to lowercase
# 3. Convert to title case
# 4. Count occurrences of the letter 'e'
# 5. Replace all spaces with underscores

# %%
message = "Hello World from Python"

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3: String Splitting and Joining
#
# 1. Split the sentence into a list of words
# 2. Join the words back together with hyphens
# 3. Split the path by the '/' separator

# %%
sentence = "The quick brown fox jumps over the lazy dog"
path = "/home/user/documents/file.txt"

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4: String Formatting
#
# Use f-strings to create formatted output:
# 1. Create a greeting with the name and age
# 2. Format the price with 2 decimal places and a dollar sign
# 3. Format the percentage with 1 decimal place and a percent sign

# %%
name = "Alice"
age = 25
price = 49.5
percentage = 87.654

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Email Validation
#
# Write code that checks if an email is valid by verifying:
# 1. It contains exactly one '@' symbol
# 2. It contains at least one '.' after the '@'
# 3. It doesn't start or end with '@' or '.'

# %%
emails = ["test@example.com", "invalid.email", "@bad.com", "good@domain.org"]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Text Cleaning
#
# Clean the messy text by:
# 1. Removing leading/trailing whitespace
# 2. Replacing multiple spaces with single spaces
# 3. Converting to lowercase
# 4. Removing punctuation

# %%
messy_text = "   Hello,    World!   How  are   you?   "

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Character Analysis
#
# Analyze the text and count:
# 1. Total characters (excluding spaces)
# 2. Number of vowels
# 3. Number of consonants
# 4. Number of digits

# %%
text = "Python 3.11 is amazing!"

# Your code here

# %% [markdown]
# ---
#
# ## Bonus Exercise: Password Strength Checker
#
# Create a password strength checker that awards points:
# - 1 point for length >= 8
# - 1 point for containing uppercase letters
# - 1 point for containing lowercase letters
# - 1 point for containing digits
# - 1 point for containing special characters (!@#$%^&*)
#
# Rate: 1-2 = Weak, 3 = Medium, 4-5 = Strong

# %%
passwords = ["abc", "Password1", "Str0ng!Pass", "12345678"]

# Your code here
