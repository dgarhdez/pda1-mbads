# %% [markdown]
# # Session 7 Homework: Conditionals and Boolean Logic
#
# Complete the following exercises to practice working with conditionals.

# %% [markdown]
# ---
#
# ## Exercise 1: Simple Conditions
#
# Write code that checks if a number is positive, negative, or zero and prints an appropriate message.

# %%
numbers = [5, -3, 0, 12, -7]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Grade Calculator
#
# Write code that converts a numeric score to a letter grade:
# - 90-100: A
# - 80-89: B
# - 70-79: C
# - 60-69: D
# - Below 60: F

# %%
scores = [95, 82, 67, 73, 55, 88]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Age Categories
#
# Categorize ages into groups:
# - 0-12: Child
# - 13-19: Teenager
# - 20-64: Adult
# - 65+: Senior

# %%
ages = [5, 15, 30, 70, 18, 45, 8]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Logical Operators
#
# A user can access premium content if:
# - They are a premium member, OR
# - They are an admin, OR
# - They have more than 1000 points
#
# Check access for each user.

# %%
users = [
    {"name": "Alice", "premium": True, "admin": False, "points": 500},
    {"name": "Bob", "premium": False, "admin": True, "points": 200},
    {"name": "Charlie", "premium": False, "admin": False, "points": 1500},
    {"name": "Diana", "premium": False, "admin": False, "points": 300}
]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Leap Year
#
# Determine if a year is a leap year. A year is a leap year if:
# - Divisible by 4 AND
# - NOT divisible by 100, OR divisible by 400

# %%
years = [2000, 2020, 1900, 2024, 2023, 1600]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Shipping Calculator
#
# Calculate shipping cost based on order total:
# - Orders under $25: $5.99 shipping
# - Orders $25-$49.99: $3.99 shipping
# - Orders $50-$99.99: Free standard shipping
# - Orders $100+: Free express shipping

# %%
order_totals = [15.00, 35.50, 75.00, 150.00, 49.99]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Input Validation
#
# Validate user input for a registration form:
# - Username: 3-20 characters, alphanumeric only
# - Age: Must be between 18 and 120
# - Email: Must contain '@' and '.'

# %%
registrations = [
    {"username": "john_doe", "age": 25, "email": "john@example.com"},
    {"username": "ab", "age": 30, "email": "valid@email.org"},
    {"username": "validuser", "age": 15, "email": "test@domain.com"},
    {"username": "goodname", "age": 40, "email": "invalid-email"}
]

# Your code here

# %% [markdown]
# ---
#
# ## Bonus Exercise: Tax Calculator
#
# Calculate tax based on income brackets:
# - $0 - $10,000: 10%
# - $10,001 - $40,000: 15%
# - $40,001 - $85,000: 25%
# - Above $85,000: 35%
#
# Note: Tax is calculated progressively (e.g., someone earning $50,000 pays 10% on first $10k, 15% on next $30k, and 25% on remaining $10k).

# %%
incomes = [8000, 25000, 50000, 100000]

# Your code here
