# %% [markdown]
# # Session 4 Homework: Data Structures II - Dictionaries and Sets
#
# Complete the following exercises to practice working with dictionaries and sets.
#
# **Instructions:**
# - Write your code in the cells provided
# - Run each cell to verify your solution

# %% [markdown]
# ---
#
# ## Exercise 1: Creating and Accessing Dictionaries
#
# Create a dictionary called `movie` with the following keys:
# - title: "Inception"
# - director: "Christopher Nolan"
# - year: 2010
# - rating: 8.8
#
# Then:
# 1. Print the movie title
# 2. Print all keys
# 3. Print all values
# 4. Check if "genre" is a key in the dictionary

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Modifying Dictionaries
#
# Using the `movie` dictionary from Exercise 1:
# 1. Add a new key "genre" with value "Sci-Fi"
# 2. Update the rating to 9.0
# 3. Use `.get()` to safely access a key that doesn't exist ("budget")
# 4. Remove the "year" key and print the dictionary

# %%
movie = {"title": "Inception", "director": "Christopher Nolan", "year": 2010, "rating": 8.8}

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Word Counter
#
# Given the sentence below, create a dictionary that counts how many times each word appears.
# Convert to lowercase before counting.

# %%
sentence = "The cat sat on the mat and the dog sat on the rug"

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Nested Dictionaries
#
# Create a nested dictionary representing a school with two classes:
# - Class A: 3 students with their grades
# - Class B: 3 students with their grades
#
# Then:
# 1. Print all students in Class A
# 2. Print a specific student's grade
# 3. Calculate the average grade for Class B

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Set Operations
#
# Given two sets representing students in different clubs:
# 1. Find students in both clubs (intersection)
# 2. Find all students in either club (union)
# 3. Find students only in the chess club (difference)
# 4. Find students in exactly one club (symmetric difference)

# %%
chess_club = {"Alice", "Bob", "Charlie", "Diana"}
debate_club = {"Bob", "Diana", "Eve", "Frank"}

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Removing Duplicates
#
# Given a list with duplicate values:
# 1. Use a set to find all unique values
# 2. Convert back to a sorted list
# 3. Count how many duplicates were removed

# %%
numbers = [5, 2, 8, 2, 9, 5, 3, 8, 1, 5, 2, 9, 3]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Dictionary from Two Lists
#
# Create a dictionary from the two lists below where `products` are keys and `prices` are values.
# Then find the most expensive product.

# %%
products = ["laptop", "phone", "tablet", "watch"]
prices = [999, 699, 449, 299]

# Your code here

# %% [markdown]
# ---
#
# ## Bonus Exercise: Inventory Management
#
# Create an inventory dictionary for a store. Each product should have:
# - price
# - quantity
# - category
#
# Then:
# 1. Calculate total inventory value (price × quantity for all items)
# 2. Find all products in a specific category
# 3. Find products with quantity less than 10

# %%
# Your code here
