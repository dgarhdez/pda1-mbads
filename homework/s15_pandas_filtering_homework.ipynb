# %% [markdown]
# # Session 15 Homework: Filtering, Selecting, and Aggregation
#
# Complete the following exercises to practice filtering and aggregating data.

# %%
import pandas as pd
import numpy as np

# Sample dataset
sales_data = {
    "product": ["Laptop", "Mouse", "Keyboard", "Monitor", "Webcam", "Headset", "Tablet", "Phone"],
    "category": ["Electronics", "Accessories", "Accessories", "Electronics", "Accessories", "Accessories", "Electronics", "Electronics"],
    "price": [999, 29, 79, 299, 89, 149, 499, 799],
    "units_sold": [50, 200, 150, 30, 100, 75, 60, 80],
    "rating": [4.5, 4.2, 4.0, 4.8, 3.9, 4.3, 4.1, 4.6],
    "in_stock": [True, True, False, True, True, True, False, True]
}

df = pd.DataFrame(sales_data)
df

# %% [markdown]
# ---
#
# ## Exercise 1: Basic Filtering
#
# Filter the DataFrame to show:
# 1. Products with price greater than 100
# 2. Products that are in stock
# 3. Products with rating >= 4.5

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Multiple Conditions
#
# Filter to find:
# 1. Electronics with price > 500
# 2. Products in stock with rating >= 4.0
# 3. Accessories that sold more than 100 units

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Using isin()
#
# Filter products that are either "Laptop", "Phone", or "Tablet".

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Using query()
#
# Use the `.query()` method to filter:
# 1. Products with price between 50 and 500
# 2. Accessories that are in stock

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Aggregation Functions
#
# Calculate:
# 1. Total revenue (price × units_sold) for all products
# 2. Average price across all products
# 3. Total units sold
# 4. Average rating

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6: GroupBy
#
# Group by category and calculate:
# 1. Average price per category
# 2. Total units sold per category
# 3. Count of products per category

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Multiple Aggregations
#
# Use `.agg()` to apply multiple functions to the "price" column grouped by category:
# - min, max, mean, sum

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Bonus Exercise: Pivot Table
#
# Create a pivot table showing:
# - Rows: category
# - Values: average price and total units_sold

# %%
# Your code here
