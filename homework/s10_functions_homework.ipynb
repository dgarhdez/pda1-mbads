# %% [markdown]
# # Session 10 Homework: Functions and Code Organization
#
# Complete the following exercises to practice writing functions.

# %% [markdown]
# ---
#
# ## Exercise 1: Basic Function
#
# Write a function `greet(name)` that returns a greeting message.

# %%
# Your code here

# Test
# print(greet("Alice"))  # Should print: Hello, Alice!

# %% [markdown]
# ---
#
# ## Exercise 2: Function with Multiple Parameters
#
# Write a function `calculate_area(length, width)` that calculates and returns the area of a rectangle.

# %%
# Your code here

# Test
# print(calculate_area(5, 3))  # Should print: 15

# %% [markdown]
# ---
#
# ## Exercise 3: Default Parameters
#
# Write a function `power(base, exponent=2)` that returns base raised to the exponent. Default exponent should be 2.

# %%
# Your code here

# Test
# print(power(5))     # Should print: 25
# print(power(2, 3))  # Should print: 8

# %% [markdown]
# ---
#
# ## Exercise 4: Multiple Return Values
#
# Write a function `min_max(numbers)` that returns both the minimum and maximum values from a list.

# %%
# Your code here

# Test
# minimum, maximum = min_max([3, 1, 4, 1, 5, 9, 2, 6])
# print(f"Min: {minimum}, Max: {maximum}")  # Should print: Min: 1, Max: 9

# %% [markdown]
# ---
#
# ## Exercise 5: Using *args
#
# Write a function `average(*args)` that accepts any number of numeric arguments and returns their average.

# %%
# Your code here

# Test
# print(average(10, 20, 30))        # Should print: 20.0
# print(average(5, 10, 15, 20, 25)) # Should print: 15.0

# %% [markdown]
# ---
#
# ## Exercise 6: Using **kwargs
#
# Write a function `build_profile(name, age, **kwargs)` that creates a dictionary with the person's name, age, and any additional information passed as keyword arguments.

# %%
# Your code here

# Test
# profile = build_profile("Alice", 25, city="Boston", job="Engineer")
# print(profile)  # Should include name, age, city, and job

# %% [markdown]
# ---
#
# ## Exercise 7: Lambda Functions
#
# Create lambda functions for:
# 1. Doubling a number
# 2. Checking if a number is even
# 3. Getting the last character of a string

# %%
# Your code here

# Test
# print(double(5))         # Should print: 10
# print(is_even(4))        # Should print: True
# print(last_char("hello"))  # Should print: o

# %% [markdown]
# ---
#
# ## Exercise 8: Function Composition
#
# Write two functions:
# 1. `celsius_to_fahrenheit(celsius)` - converts Celsius to Fahrenheit
# 2. `fahrenheit_to_kelvin(fahrenheit)` - converts Fahrenheit to Kelvin
#
# Then write a third function `celsius_to_kelvin(celsius)` that uses both functions.

# %%
# Your code here

# Test
# print(celsius_to_kelvin(0))    # Should print approximately 273.15
# print(celsius_to_kelvin(100))  # Should print approximately 373.15

# %% [markdown]
# ---
#
# ## Bonus Exercise: Decorator
#
# Write a simple decorator `timer` that prints how long a function takes to execute.

# %%
import time

# Your code here

# Test
# @timer
# def slow_function():
#     time.sleep(1)
#     return "Done!"
# 
# result = slow_function()  # Should print execution time
