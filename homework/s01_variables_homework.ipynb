# %% [markdown]
# # Session 1 Homework: Variables, Types, and Basic Operations
#
# Complete the following exercises to practice what you learned in Session 1.
#
# **Instructions:**
# - Write your code in the cells provided
# - Run each cell to verify your solution
# - Make sure to follow the naming conventions specified in each exercise

# %% [markdown]
# ---
#
# ## Exercise 1: Creating Variables
#
# Create the following variables:
# 1. `student_name` - your name as a string
# 2. `student_age` - your age as an integer
# 3. `student_gpa` - a GPA as a float (e.g., 3.75)
# 4. `is_enrolled` - a boolean indicating enrollment status
#
# Print each variable along with its type.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Arithmetic Operations
#
# A store is having a sale. Given the following information:
# - Original price: $85.00
# - Discount: 20%
# - Tax rate: 8%
#
# Calculate:
# 1. The discount amount (store in `discount_amount`)
# 2. The price after discount (store in `discounted_price`)
# 3. The tax amount on the discounted price (store in `tax_amount`)
# 4. The final price including tax (store in `final_price`)
#
# Print all results formatted to 2 decimal places.

# %%
original_price = 85.00
discount_rate = 0.20
tax_rate = 0.08

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Temperature Conversion
#
# Write code that:
# 1. Converts 100°F to Celsius using the formula: C = (F - 32) × 5/9
# 2. Converts 37°C to Fahrenheit using the formula: F = C × 9/5 + 32
#
# Store results in `celsius_result` and `fahrenheit_result`, and print both.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Integer Division and Modulo
#
# You have 127 students that need to be divided into groups of 8.
#
# Using integer division (`//`) and modulo (`%`), calculate:
# 1. How many complete groups can be formed? (store in `complete_groups`)
# 2. How many students will be left over? (store in `remaining_students`)
#
# Print the results in a sentence.

# %%
total_students = 127
group_size = 8

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Type Conversion
#
# Given the following variables, perform the required conversions:
#
# 1. Convert `price_str` to a float and add 10 to it
# 2. Convert `quantity_float` to an integer
# 3. Convert `is_available_int` to a boolean
# 4. Create a string that combines the converted values in a sentence

# %%
price_str = "49.99"
quantity_float = 3.7
is_available_int = 1

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6: BMI Calculator
#
# Body Mass Index (BMI) is calculated as: BMI = weight (kg) / height (m)²
#
# Given a person's weight and height:
# 1. Calculate the BMI (store in `bmi`)
# 2. Round the BMI to 1 decimal place (store in `bmi_rounded`)
# 3. Print the result with an appropriate message

# %%
weight_kg = 70
height_m = 1.75

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Variable Reassignment
#
# Demonstrate variable reassignment by:
# 1. Creating a variable `counter` with value 0
# 2. Incrementing it by 5 using `+=`
# 3. Multiplying it by 2 using `*=`
# 4. Subtracting 3 using `-=`
#
# Print the value after each operation.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Bonus Exercise: Investment Calculator
#
# Calculate the future value of an investment using compound interest:
#
# A = P(1 + r/n)^(nt)
#
# Where:
# - P = Principal (initial investment)
# - r = Annual interest rate (as decimal)
# - n = Number of times compounded per year
# - t = Number of years
#
# Calculate and print:
# 1. The future value after 5 years
# 2. The total interest earned

# %%
principal = 10000  # $10,000 initial investment
annual_rate = 0.06  # 6% annual interest
compounds_per_year = 4  # Quarterly compounding
years = 5

# Your code here
