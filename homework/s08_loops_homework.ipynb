# %% [markdown]
# # Session 8 Homework: Loops and Iteration
#
# Complete the following exercises to practice working with loops.

# %% [markdown]
# ---
#
# ## Exercise 1: Basic For Loop
#
# Print all even numbers from 2 to 20 using a for loop with `range()`.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Sum Calculator
#
# Calculate the sum of all numbers from 1 to 100 using a loop.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Enumerate Practice
#
# Given a list of fruits, print each fruit with its position (starting from 1) using `enumerate()`.

# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry"]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Zip Practice
#
# Given two lists, use `zip()` to create a list of tuples pairing names with their scores.

# %%
names = ["Alice", "Bob", "Charlie", "Diana"]
scores = [85, 92, 78, 95]

# Your code here

# %% [markdown]
# ---
#
# ## Exercise 5: While Loop
#
# Use a while loop to find the first power of 2 that is greater than 1000.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Break and Continue
#
# Loop through numbers 1-20:
# - Skip numbers divisible by 3 (use `continue`)
# - Stop when you reach a number divisible by 7 (use `break`)
# - Print all other numbers

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Nested Loops
#
# Create a multiplication table for numbers 1-5 using nested loops.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Exercise 8: Looping Through Dictionaries
#
# Loop through the dictionary and print each person's information formatted nicely.

# %%
people = {
    "Alice": {"age": 25, "city": "New York"},
    "Bob": {"age": 30, "city": "Boston"},
    "Charlie": {"age": 35, "city": "Chicago"}
}

# Your code here

# %% [markdown]
# ---
#
# ## Bonus Exercise: Fibonacci Sequence
#
# Generate the first 15 Fibonacci numbers using a loop.

# %%
# Your code here
